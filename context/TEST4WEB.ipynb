# %%
# ================= IMPORTING LIBRARIES =================
import os, cv2, hashlib, time, pathlib
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, Input
from sklearn.preprocessing import LabelEncoder, StandardScaler, label_binarize
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_auc_score
import warnings
warnings.filterwarnings("ignore")

# ================= REPRODUCIBILITY =================
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)
os.environ['PYTHONHASHSEED'] = str(RANDOM_STATE)


# ================= CONFIG =================
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 20
AUTOTUNE = tf.data.AUTOTUNE


# GPU SETUP
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# ============================================================
# PRE-SPLIT CSV FILES
# ============================================================

TRAIN_CSV = r"C:\Users\ALFA\Codes\Optical_Coherence_Tomography\Training\ORIGINAL_OCTDL_DATA_REDUCED\OCT_SPLIT\train_augmented.csv"

VAL_CSV = r"C:\Users\ALFA\Codes\Optical_Coherence_Tomography\Training\ORIGINAL_OCTDL_DATA_REDUCED\OCT_SPLIT\validation.csv"

TEST_CSV = r"C:\Users\ALFA\Codes\Optical_Coherence_Tomography\Training\ORIGINAL_OCTDL_DATA_REDUCED\OCT_SPLIT\test.csv"

# ============================================================
# IMAGE DIRECTORIES
# ============================================================

TRAIN_DIR = r"C:\Users\ALFA\Codes\Optical_Coherence_Tomography\Training\ORIGINAL_OCTDL_DATA_REDUCED\OCT_SPLIT\train"

VAL_DIR = r"C:\Users\ALFA\Codes\Optical_Coherence_Tomography\Training\ORIGINAL_OCTDL_DATA_REDUCED\OCT_SPLIT\validation"

TEST_DIR = r"C:\Users\ALFA\Codes\Optical_Coherence_Tomography\Training\ORIGINAL_OCTDL_DATA_REDUCED\OCT_SPLIT\test"

# ================= LOAD PRE-SPLIT CSV FILES =================

train_df = pd.read_csv(TRAIN_CSV)
val_df   = pd.read_csv(VAL_CSV)
test_df  = pd.read_csv(TEST_CSV)


# ================= IMAGE FINDER =================

def find_image_file(base_dir, disease, file_name):

    file_name = pathlib.Path(str(file_name)).stem

    for ext in ['', '.jpg', '.png', '.jpeg', '.tif']:

        p1 = os.path.join(
            base_dir,
            str(disease),
            f"{file_name}{ext}"
        )

        p2 = os.path.join(
            base_dir,
            f"{file_name}{ext}"
        )

        if os.path.exists(p1):
            return p1

        if os.path.exists(p2):
            return p2

    return None

# ================= LOAD IMAGE PATHS =================

train_df['filepath'] = train_df.apply(
    lambda r: find_image_file(
        TRAIN_DIR,
        r['disease'],
        r['file_name']
    ),
    axis=1
)

val_df['filepath'] = val_df.apply(
    lambda r: find_image_file(
        VAL_DIR,
        r['disease'],
        r['file_name']
    ),
    axis=1
)

test_df['filepath'] = test_df.apply(
    lambda r: find_image_file(
        TEST_DIR,
        r['disease'],
        r['file_name']
    ),
    axis=1
)

# ================= REMOVE MISSING FILES =================

train_df = train_df.dropna(subset=['filepath']).reset_index(drop=True)
val_df   = val_df.dropna(subset=['filepath']).reset_index(drop=True)
test_df  = test_df.dropna(subset=['filepath']).reset_index(drop=True)

print("\n=== DATA LOADING SUMMARY ===")
print("Train images:", len(train_df))
print("Validation images:", len(val_df))
print("Test images:", len(test_df))

# ================= PATIENT-LEVEL CHECK =================

print("\n=== PATIENT-LEVEL SPLIT CHECK ===")

train_patients = set(train_df['patient_id'])
val_patients   = set(val_df['patient_id'])
test_patients  = set(test_df['patient_id'])

print("Train-Val overlap :", len(train_patients & val_patients))
print("Train-Test overlap:", len(train_patients & test_patients))
print("Val-Test overlap  :", len(val_patients & test_patients))

if (
    len(train_patients & val_patients) == 0 and
    len(train_patients & test_patients) == 0 and
    len(val_patients & test_patients) == 0
):
    print("✅ Perfect patient-level split (no leakage)")
else:
    print("❌ Patient leakage detected!")

# ================= DUPLICATE CHECK =================

def hash_image(path):
    with open(path, 'rb') as f:
        return hashlib.md5(f.read()).hexdigest()

print("\n=== DUPLICATE IMAGE CHECK ===")

combined_df = pd.concat(
    [train_df, val_df, test_df],
    ignore_index=True
)

combined_df['img_hash'] = combined_df['filepath'].apply(hash_image)

duplicate_counts = combined_df['img_hash'].value_counts()
num_duplicate_images = (duplicate_counts > 1).sum()

print("Images with duplicates:", num_duplicate_images)

cross_patient_dup = combined_df.groupby('img_hash')['patient_id'].nunique()
cross_patient_dup = cross_patient_dup[cross_patient_dup > 1]

print("Cross-patient duplicate images:", len(cross_patient_dup))

if len(cross_patient_dup) > 0:
    print("⚠️ WARNING: Data leakage risk detected!")
else:
    print("✅ No cross-patient leakage from duplicate images")


# ============================================================
# REMOVE DUPLICATE IMAGES
# ============================================================

print("\n=== REMOVING DUPLICATE IMAGES ===")

# ---------------- REMOVE EXACT DUPLICATES ----------------

before_total = len(combined_df)

combined_df = combined_df.drop_duplicates(
    subset='img_hash',
    keep='first'
).reset_index(drop=True)

after_total = len(combined_df)

print(f"Removed duplicate images: {before_total - after_total}")
print(f"Remaining unique images: {after_total}")

# ---------------- REMOVE CROSS-PATIENT DUPLICATES ----------------

cross_patient_dup = combined_df.groupby('img_hash')['patient_id'].nunique()
cross_patient_hashes = cross_patient_dup[
    cross_patient_dup > 1
].index

if len(cross_patient_hashes) > 0:

    print(f"Removing cross-patient duplicates: {len(cross_patient_hashes)}")

    combined_df = combined_df[
        ~combined_df['img_hash'].isin(cross_patient_hashes)
    ].reset_index(drop=True)

else:
    print("No cross-patient duplicates found")

# ============================================================
# SPLIT BACK INTO TRAIN / VAL / TEST
# ============================================================

train_df = combined_df[
    combined_df['filepath'].str.contains(TRAIN_DIR, regex=False)
].reset_index(drop=True)

val_df = combined_df[
    combined_df['filepath'].str.contains(VAL_DIR, regex=False)
].reset_index(drop=True)

test_df = combined_df[
    combined_df['filepath'].str.contains(TEST_DIR, regex=False)
].reset_index(drop=True)

# ============================================================
# FINAL DUPLICATE CHECK
# ============================================================

print("\n=== FINAL DUPLICATE CHECK ===")

final_duplicate_count = combined_df['img_hash'].duplicated().sum()

print("Remaining duplicates:", final_duplicate_count)

if final_duplicate_count == 0:
    print("✅ All duplicate images removed successfully")
else:
    print("⚠️ Some duplicates still remain")

# ============================================================
# UPDATED DATA SUMMARY
# ============================================================

print("\n=== UPDATED DATASET SUMMARY ===")
print("Train images:", len(train_df))
print("Validation images:", len(val_df))
print("Test images:", len(test_df))

# ================= ENCODING =================

disease_encoder = LabelEncoder()
severity_encoder = LabelEncoder()

combined_df['disease_encoded'] = disease_encoder.fit_transform(
    combined_df['disease']
)

combined_df['severity_encoded'] = severity_encoder.fit_transform(
    combined_df['severity_level']
)



# ================= APPLY ENCODING BACK =================

encoding_cols = [
    'file_name',
    'disease_encoded',
    'severity_encoded'
]

train_df = train_df.merge(
    combined_df[encoding_cols],
    on='file_name',
    how='left'
)

val_df = val_df.merge(
    combined_df[encoding_cols],
    on='file_name',
    how='left'
)

test_df = test_df.merge(
    combined_df[encoding_cols],
    on='file_name',
    how='left'
)



# ============================================================
# INTERNAL DUPLICATE IMAGE CHECK
# ============================================================

import hashlib

def hash_image(path):

    with open(path, 'rb') as f:
        return hashlib.md5(f.read()).hexdigest()

# ============================================================
# FUNCTION TO CHECK DUPLICATES
# ============================================================

def check_internal_duplicates(name, df):

    print(f"\n=== {name} INTERNAL DUPLICATE CHECK ===")

    # create image hashes
    df = df.copy()

    df['img_hash'] = df['filepath'].apply(hash_image)

    # count duplicates
    duplicate_count = df['img_hash'].duplicated().sum()

    print("Duplicate images:", duplicate_count)

    # show duplicated rows
    duplicated_rows = df[
        df['img_hash'].duplicated(keep=False)
    ].sort_values('img_hash')

    if len(duplicated_rows) > 0:

        print("\nSample duplicated entries:")

        print(
            duplicated_rows[
                ['patient_id', 'disease', 'file_name']
            ].head(10)
        )

    else:
        print("✅ No internal duplicates found")

# ============================================================
# RUN CHECKS
# ============================================================

check_internal_duplicates("TRAIN", train_df)

check_internal_duplicates("VALIDATION", val_df)

check_internal_duplicates("TEST", test_df)

# ================= OVERALL DISTRIBUTION =================

print("\n=== TRAIN DISTRIBUTION ===")
print(train_df['disease'].value_counts())

print("\n=== VALIDATION DISTRIBUTION ===")
print(val_df['disease'].value_counts())

print("\n=== TEST DISTRIBUTION ===")
print(test_df['disease'].value_counts())

# ================= BAR CHART =================

import matplotlib.pyplot as plt

train_counts = train_df['disease'].value_counts()
val_counts   = val_df['disease'].value_counts()
test_counts  = test_df['disease'].value_counts()

split_dist = pd.DataFrame({
    'Train': train_counts,
    'Validation': val_counts,
    'Test': test_counts
}).fillna(0)

ax = split_dist.plot(
    kind='bar',
    figsize=(9,6),
    width=0.9
)

plt.title(
    'Disease Distribution Across Train, Validation, and Test Sets',
    pad=15
)

plt.xlabel('Disease')
plt.ylabel('Number of Images')

plt.xticks(rotation=45)
plt.legend(title='Dataset Split')

for container in ax.containers:
    ax.bar_label(container, fmt='%d', padding=2)

plt.tight_layout()
plt.show()

# ================= FEATURE ENGINEERING =================

for df_ in [train_df, val_df, test_df]:

    df_.fillna({
        'sex':'unknown',
        'eye':'unknown'
    }, inplace=True)

    df_['age'] = 2024 - df_['year']

    df_['aspect_ratio'] = (
        df_['image_width'] /
        (df_['image_hight'] + 1e-6)
    )

# ================= SCALING =================

num_cols = [
    'image_width',
    'image_hight',
    'aspect_ratio'
]

scaler = StandardScaler()

train_scaled = scaler.fit_transform(train_df[num_cols])
val_scaled   = scaler.transform(val_df[num_cols])
test_scaled  = scaler.transform(test_df[num_cols])

for i, c in enumerate(num_cols):

    train_df[f'scaled_{c}'] = train_scaled[:, i]
    val_df[f'scaled_{c}']   = val_scaled[:, i]
    test_df[f'scaled_{c}']  = test_scaled[:, i]

# ================= ENCODING =================

for c in ['sex', 'eye']:

    le = LabelEncoder()

    train_df[f'{c}_encoded'] = le.fit_transform(train_df[c])

    val_df[f'{c}_encoded'] = le.transform(val_df[c])

    test_df[f'{c}_encoded'] = le.transform(test_df[c])

feature_cols = [
    c for c in train_df.columns
    if c.startswith('scaled_') or c.endswith('_encoded')
]

train_clinical = train_df[feature_cols].values.astype(np.float32)
val_clinical   = val_df[feature_cols].values.astype(np.float32)
test_clinical  = test_df[feature_cols].values.astype(np.float32)

# ================= DATASET =================

def load_and_preprocess_image(path):

    def _read(p):

        p = p.decode()

        img = cv2.imread(
            p,
            cv2.IMREAD_GRAYSCALE
        )

        img = cv2.resize(
            img,
            IMAGE_SIZE
        )

        img = (
            img - img.mean()
        ) / (
            img.std() + 1e-6
        )

        return img[..., None].astype(np.float32)

    img = tf.numpy_function(
        _read,
        [path],
        tf.float32
    )

    img.set_shape((*IMAGE_SIZE, 1))

    return img

# COMPUTE CLASS WEIGHTS (TRAIN ONLY) 
disease_classes = np.unique(train_df['disease_encoded'])
severity_classes = np.unique(train_df['severity_encoded'])

disease_class_weights = dict(zip(
    disease_classes,
    compute_class_weight(
        class_weight='balanced',
        classes=disease_classes,
        y=train_df['disease_encoded']
    )
))

severity_class_weights = dict(zip(
    severity_classes,
    compute_class_weight(
        class_weight='balanced',
        classes=severity_classes,
        y=train_df['severity_encoded']
    )
))

print("Disease class weights:", disease_class_weights)
print("Severity class weights:", severity_class_weights)


def make_dataset(df, clinical, shuffle=True, use_weights=False):

    if use_weights:

        disease_sw = df['disease_encoded'].map(
            disease_class_weights
        ).values.astype(np.float32)

        severity_sw = df['severity_encoded'].map(
            severity_class_weights
        ).values.astype(np.float32)

        ds = tf.data.Dataset.from_tensor_slices(
            (
                (
                    df['filepath'].values,
                    clinical
                ),
                {
                    'disease_output': df['disease_encoded'].values,
                    'severity_output': df['severity_encoded'].values
                },
                {
                    'disease_output': disease_sw,
                    'severity_output': severity_sw
                }
            )
        )

    else:

        ds = tf.data.Dataset.from_tensor_slices(
            (
                (
                    df['filepath'].values,
                    clinical
                ),
                {
                    'disease_output': df['disease_encoded'].values,
                    'severity_output': df['severity_encoded'].values
                }
            )
        )

    if shuffle:
        ds = ds.shuffle(
            len(df),
            seed=RANDOM_STATE,
            reshuffle_each_iteration=False
        )

    options = tf.data.Options()
    options.experimental_deterministic = True
    ds = ds.with_options(options)

    if use_weights:

        def map_fn(x, y, sw):

            img = load_and_preprocess_image(x[0])

            return (img, x[1]), y, sw

    else:

        def map_fn(x, y):

            img = load_and_preprocess_image(x[0])

            return (img, x[1]), y

    return ds.map(
        map_fn,
        num_parallel_calls=AUTOTUNE
    ).batch(BATCH_SIZE).prefetch(AUTOTUNE)

train_ds = make_dataset(
    train_df,
    train_clinical,
    shuffle=True,
    use_weights=True
)

val_ds = make_dataset(
    val_df,
    val_clinical,
    shuffle=False,
    use_weights=False
)

test_ds = make_dataset(
    test_df,
    test_clinical,
    shuffle=False,
    use_weights=False
)

# ================= CBAM =================
def channel_attention(x, ratio=8):
    ch = x.shape[-1]
    avg = layers.GlobalAveragePooling2D()(x)
    maxp = layers.GlobalMaxPooling2D()(x)
    shared_1 = layers.Dense(ch//ratio, activation='relu')
    shared_2 = layers.Dense(ch, activation='sigmoid')
    avg_out = shared_2(shared_1(avg))
    max_out = shared_2(shared_1(maxp))
    scale = layers.Add()([avg_out, max_out])
    scale = layers.Reshape((1,1,ch))(scale)
    return layers.Multiply()([x, scale])

def spatial_attention(x):
    avg = tf.reduce_mean(x, axis=-1, keepdims=True)
    maxp = tf.reduce_max(x, axis=-1, keepdims=True)
    concat = layers.Concatenate()([avg, maxp])
    attn = layers.Conv2D(1, 7, padding='same', activation='sigmoid')(concat)
    return layers.Multiply()([x, attn])

def cbam_block(x):
    return spatial_attention(channel_attention(x))

# ================= CROSS-MODAL FUSION =================
def cross_modal_fusion(img_feat, clin_feat):

    fused_features = layers.Concatenate()([
        img_feat,
        clin_feat
    ])

    return fused_features
    
# ================= MODEL =================
def build():
    img = Input((*IMAGE_SIZE, 1), name='input_image')
    clin = Input((len(feature_cols),), name='input_clinical')

    x = layers.Conv2D(32,3,padding='same',activation='relu')(img)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool2D()(x)

    x = layers.Conv2D(64,3,padding='same',activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool2D()(x)

    x = layers.Conv2D(128,3,padding='same',activation='relu')(x)
    x = layers.MaxPool2D()(x)

    x = layers.Conv2D(256,3,padding='same',activation='relu',name='conv4_256')(x)
    x = cbam_block(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.LayerNormalization()(x)

    y = layers.Dense(64,activation='relu')(clin)
    y = layers.BatchNormalization()(y)
    y = layers.Dense(64,activation='relu')(y)
    y = layers.LayerNormalization()(y)

    z = cross_modal_fusion(x, y)
    z = layers.Dense(128,activation='relu')(z)
    z = layers.BatchNormalization()(z)
    z = layers.Dropout(0.6)(z)

    disease = layers.Dense(len(disease_encoder.classes_),activation='softmax',name='disease_output')(z)
    severity = layers.Dense(len(severity_encoder.classes_),activation='softmax',name='severity_output')(z)

    return Model([img, clin],[disease, severity])

model = build()

model.summary()

model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss={'disease_output':'sparse_categorical_crossentropy','severity_output':'sparse_categorical_crossentropy'},
    loss_weights={'disease_output':0.6,'severity_output':0.4},
    metrics={'disease_output':['accuracy'],'severity_output':['accuracy']}
)

print("\n=== MODEL READY: CBAM + CROSS-MODAL FUSION ===")

# ============================================================
# SAVE BEST MODEL
# ============================================================

checkpoint = keras.callbacks.ModelCheckpoint(
        filepath='best_oct_model.keras',
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=1
)

history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=EPOCHS,
    callbacks=[
        checkpoint,
        keras.callbacks.EarlyStopping(monitor='val_loss', 
                                      patience=6, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                          factor=0.3, patience=4, min_lr=1e-6)
    ]
 )

# ============================================================
# LOAD BEST SAVED MODEL
# ============================================================

best_model = keras.models.load_model(
    'best_oct_model.keras'
)

# ================= MACRO AUC =================
y_pred_disease, y_pred_severity = best_model.predict(test_ds)

macro_auc_disease = roc_auc_score(
    label_binarize(test_df['disease_encoded'], classes=np.unique(test_df['disease_encoded'])),
    y_pred_disease, average='macro', multi_class='ovr')

macro_auc_severity = roc_auc_score(
    label_binarize(test_df['severity_encoded'], classes=np.unique(test_df['severity_encoded'])),
    y_pred_severity, average='macro', multi_class='ovr')

# ============================================================
# INFERENCE TIME BENCHMARK (MODEL FORWARD PASS ONLY)
# ============================================================

import time
import numpy as np

# Get one batch
sample_batch = next(iter(test_ds))
imgs, clin = sample_batch[0]

# Warm-up GPU/CPU
for _ in range(10):
    _ = best_model([imgs, clin], training=False)

# Benchmark
n_runs = 100

start = time.perf_counter()

for _ in range(n_runs):
    _ = best_model([imgs, clin], training=False)

end = time.perf_counter()

# Average batch inference time
avg_batch_time = (end - start) / n_runs

# Average inference time per image
batch_size = imgs.shape[0]
time_per_image = avg_batch_time / batch_size

# ================= FINAL METRICS =================
from sklearn.metrics import accuracy_score, cohen_kappa_score

y_pred_disease_labels = np.argmax(y_pred_disease, axis=1)
y_pred_severity_labels = np.argmax(y_pred_severity, axis=1)

# ===== INDIVIDUAL TASK METRICS =====
acc_disease = accuracy_score(test_df['disease_encoded'], y_pred_disease_labels)
acc_severity = accuracy_score(test_df['severity_encoded'], y_pred_severity_labels)

kappa_disease = cohen_kappa_score(test_df['disease_encoded'], y_pred_disease_labels)
kappa_severity = cohen_kappa_score(test_df['severity_encoded'], y_pred_severity_labels)

# ===== COMBINED (ORIGINAL BEHAVIOR - UNCHANGED) =====
acc = (acc_disease + acc_severity) / 2
kappa = (kappa_disease + kappa_severity) / 2
macro_auc = (macro_auc_disease + macro_auc_severity) / 2
inference_time = end - start
time_per_image = inference_time / len(test_df)

# ===== PRINT CLEAN RESULTS =====
print("\n================ FINAL RESULTS ================\n")

print("----- DISEASE TASK -----")
print(f"Accuracy       : {acc_disease:.3f}")
print(f"Kappa          : {kappa_disease:.3f}")
print(f"Macro AUC      : {macro_auc_disease:.3f}")

print("\n----- SEVERITY TASK -----")
print(f"Accuracy       : {acc_severity:.3f}")
print(f"Kappa          : {kappa_severity:.3f}")
print(f"Macro AUC      : {macro_auc_severity:.3f}")

print("\n----- COMBINED (AVERAGE) -----")
print(f"Accuracy       : {acc:.3f}")
print(f"Kappa          : {kappa:.3f}")
print(f"Macro AUC      : {macro_auc:.3f}")

print("\n=========== COMPUTATIONAL INFERENCE TIME RESULTS ===========")
print(f"Batch Size           : {batch_size}")
print(f"Average Batch Time   : {avg_batch_time:.6f} sec")
print(f"Average Image Time   : {time_per_image:.6f} sec")
print(f"Inference Time/Image : {time_per_image*1000:.3f} ms")
# Out:
# === DATA LOADING SUMMARY ===
# Train images: 3650
# Validation images: 299
# Test images: 296
#
# === PATIENT-LEVEL SPLIT CHECK ===
# Train-Val overlap : 0
# Train-Test overlap: 0
# Val-Test overlap  : 0
# ✅ Perfect patient-level split (no leakage)
#
# === DUPLICATE IMAGE CHECK ===
# Images with duplicates: 103
# Cross-patient duplicate images: 2
# ⚠️ WARNING: Data leakage risk detected!
#
# === REMOVING DUPLICATE IMAGES ===
# Removed duplicate images: 149
# Remaining unique images: 4096
# No cross-patient duplicates found
#
# === FINAL DUPLICATE CHECK ===
# Remaining duplicates: 0
# ✅ All duplicate images removed successfully
#
# === UPDATED DATASET SUMMARY ===
# Train images: 3501
# Validation images: 299
# Test images: 296
#
# === TRAIN INTERNAL DUPLICATE CHECK ===
# Duplicate images: 0
# ✅ No internal duplicates found
#
# === VALIDATION INTERNAL DUPLICATE CHECK ===
# Duplicate images: 0
# ✅ No internal duplicates found
#
# === TEST INTERNAL DUPLICATE CHECK ===
# Duplicate images: 0
# ✅ No internal duplicates found
#
# === TRAIN DISTRIBUTION ===
# disease
# AMD    998
# NO     783
# DME    604
# ERM    600
# RVO    516
# Name: count, dtype: int64
#
# === VALIDATION DISTRIBUTION ===
# disease
# AMD    186
# NO      55
# ERM     27
# DME     21
# RVO     10
# Name: count, dtype: int64
#
# === TEST DISTRIBUTION ===
# disease
# AMD    185
# NO      55
# ERM     26
# DME     20
# RVO     10
# Name: count, dtype: int64
# Disease class weights: {0: 0.7016032064128257, 1: 1.159271523178808, 2: 1.167, 3: 0.8942528735632184, 4: 1.3569767441860465}
# Severity class weights: {0: 3.399029126213592, 1: 3.764516129032258, 2: 0.36223486808070354, 3: 1.7161764705882352, 4: 0.91171875}
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 32  320         ['input_image[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 128)  0          ['conv2d_2[0][0]']
#
#  conv4_256 (Conv2D)             (None, 28, 28, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['conv4_256[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 256)         0           ['conv4_256[0][0]']
#  xPooling2D)
#
#  dense (Dense)                  (None, 32)           8224        ['global_average_pooling2d[0][0]'
#                                                                  , 'global_max_pooling2d[0][0]']
#
#  dense_1 (Dense)                (None, 256)          8448        ['dense[0][0]',
#                                                                   'dense[1][0]']
#
#  add (Add)                      (None, 256)          0           ['dense_1[0][0]',
#                                                                   'dense_1[1][0]']
#
#  reshape (Reshape)              (None, 1, 1, 256)    0           ['add[0][0]']
#
#  multiply (Multiply)            (None, 28, 28, 256)  0           ['conv4_256[0][0]',
#                                                                   'reshape[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  (None, 28, 28, 1)   0           ['multiply[0][0]']
#  a)
#
#  tf.math.reduce_max (TFOpLambda  (None, 28, 28, 1)   0           ['multiply[0][0]']
#  )
#
#  concatenate (Concatenate)      (None, 28, 28, 2)    0           ['tf.math.reduce_mean[0][0]',
#                                                                   'tf.math.reduce_max[0][0]']
#
#  input_clinical (InputLayer)    [(None, 7)]          0           []
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 1)    99          ['concatenate[0][0]']
#
#  dense_2 (Dense)                (None, 64)           512         ['input_clinical[0][0]']
#
#  multiply_1 (Multiply)          (None, 28, 28, 256)  0           ['multiply[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64)          256         ['dense_2[0][0]']
#  rmalization)
#
#  global_average_pooling2d_1 (Gl  (None, 256)         0           ['multiply_1[0][0]']
#  obalAveragePooling2D)
#
#  dense_3 (Dense)                (None, 64)           4160        ['batch_normalization_2[0][0]']
#
#  layer_normalization (LayerNorm  (None, 256)         512         ['global_average_pooling2d_1[0][0
#  alization)                                                      ]']
#
#  layer_normalization_1 (LayerNo  (None, 64)          128         ['dense_3[0][0]']
#  rmalization)
#
#  concatenate_1 (Concatenate)    (None, 320)          0           ['layer_normalization[0][0]',
#                                                                   'layer_normalization_1[0][0]']
#
#  dense_4 (Dense)                (None, 128)          41088       ['concatenate_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 128)         512         ['dense_4[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 128)          0           ['batch_normalization_3[0][0]']
#
#  disease_output (Dense)         (None, 5)            645         ['dropout[0][0]']
#
#  severity_output (Dense)        (None, 5)            645         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 453,453
# Trainable params: 452,877
# Non-trainable params: 576
# __________________________________________________________________________________________________
#
# === MODEL READY: CBAM + CROSS-MODAL FUSION ===
# Epoch 1/20
# 110/110 [==============================] - ETA: 0s - loss: 1.7234 - disease_output_loss: 1.6165 - severity_output_loss: 1.8837 - disease_output_accuracy: 0.4242 - severity_output_accuracy: 0.3570
# Epoch 1: val_loss improved from inf to 1.30118, saving model to best_oct_model.keras
# 110/110 [==============================] - 37s 150ms/step - loss: 1.7234 - disease_output_loss: 1.6165 - severity_output_loss: 1.8837 - disease_output_accuracy: 0.4242 - severity_output_accuracy: 0.3570 - val_loss: 1.3012 - val_disease_output_loss: 1.1643 - val_severity_output_loss: 1.5065 - val_disease_output_accuracy: 0.5050 - val_severity_output_accuracy: 0.2475 - lr: 1.0000e-04
# Epoch 2/20
# 110/110 [==============================] - ETA: 0s - loss: 1.0026 - disease_output_loss: 0.8742 - severity_output_loss: 1.1952 - disease_output_accuracy: 0.6627 - severity_output_accuracy: 0.5067
# Epoch 2: val_loss improved from 1.30118 to 1.06521, saving model to best_oct_model.keras
# 110/110 [==============================] - 14s 129ms/step - loss: 1.0026 - disease_output_loss: 0.8742 - severity_output_loss: 1.1952 - disease_output_accuracy: 0.6627 - severity_output_accuracy: 0.5067 - val_loss: 1.0652 - val_disease_output_loss: 0.8014 - val_severity_output_loss: 1.4609 - val_disease_output_accuracy: 0.7090 - val_severity_output_accuracy: 0.4582 - lr: 1.0000e-04
# Epoch 3/20
# 110/110 [==============================] - ETA: 0s - loss: 0.7187 - disease_output_loss: 0.6238 - severity_output_loss: 0.8611 - disease_output_accuracy: 0.7646 - severity_output_accuracy: 0.6084
# Epoch 3: val_loss improved from 1.06521 to 0.60524, saving model to best_oct_model.keras
# 110/110 [==============================] - 14s 128ms/step - loss: 0
accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 20/20
# 110/110 [==============================] - ETA: 0s - loss: 0.0507 - disease_output_loss: 0.0380 - severity_output_loss: 0.0698 - disease_output_accuracy: 0.9951 - severity_output_accuracy: 0.9797
# Epoch 20: val_loss did not improve from 0.03916
# 110/110 [==============================] - 14s 126ms/step - loss: 0.0507 - disease_output_loss: 0.0380 - severity_output_loss: 0.0698 - disease_output_accuracy: 0.9951 - severity_output_accuracy: 0.9797 - val_loss: 0.0536 - val_disease_output_loss: 0.0590 - val_severity_output_loss: 0.0456 - val_disease_output_accuracy: 0.9766 - val_severity_output_accuracy: 0.9967 - lr: 1.0000e-04
# 10/10 [==============================] - 1s 70ms/step
#
# ================ FINAL RESULTS ================
#
# ----- DISEASE TASK -----
# Accuracy       : 0.983
# Kappa          : 0.970
# Macro AUC      : 0.999
#
# ----- SEVERITY TASK -----
# Accuracy       : 0.997
# Kappa          : 0.995
# Macro AUC      : 1.000
#
# ----- COMBINED (AVERAGE) -----
# Accuracy       : 0.990
# Kappa          : 0.983
# Macro AUC      : 1.000
#
# =========== COMPUTATIONAL INFERENCE TIME RESULTS ===========
# Batch Size           : 32
# Average Batch Time   : 0.048974 sec
# Average Image Time   : 0.016545 sec
# Inference Time/Image : 16.545 ms

# %%
import joblib

# %%
model.save("best_oct_model.keras")
joblib.dump(disease_encoder, 'disease_encoder.pkl')
joblib.dump(severity_encoder, 'severity_encoder.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
print("\n=== FINAL TEST EVALUATION ===")
results = best_model.evaluate(test_ds, return_dict=True)

for k, v in results.items():
    print(f"{k}: {v:.2f}")
# Out:
# === FINAL TEST EVALUATION ===
# 10/10 [==============================] - 2s 81ms/step - loss: 0.0446 - disease_output_loss: 0.0516 - severity_output_loss: 0.0343 - disease_output_accuracy: 0.9831 - severity_output_accuracy: 0.9966
# loss: 0.04
# disease_output_loss: 0.05
# severity_output_loss: 0.03
# disease_output_accuracy: 0.98
# severity_output_accuracy: 1.00

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# FIRST, COLLECT ALL PREDICTIONS 
print("Collecting predictions...")


y_true_disease = []
y_pred_disease = []
y_true_severity = []
y_pred_severity = []

for (imgs, clin), targets in test_ds:
    disease_probs, severity_probs = model.predict((imgs, clin), verbose=0)
    y_pred_disease.extend(np.argmax(disease_probs, axis=1))
    y_pred_severity.extend(np.argmax(severity_probs, axis=1))
    y_true_disease.extend(targets['disease_output'].numpy())
    y_true_severity.extend(targets['severity_output'].numpy())


y_true_disease = np.array(y_true_disease)
y_pred_disease = np.array(y_pred_disease)
y_true_severity = np.array(y_true_severity)
y_pred_severity = np.array(y_pred_severity)

print(f"Collected {len(y_true_disease)} samples")

# CREATE BOTH CONFUSION MATRICES 
# Disease confusion matrix
cm_disease = confusion_matrix(y_true_disease, y_pred_disease)
cm_disease_percent = cm_disease.astype('float') / cm_disease.sum(axis=1)[:, np.newaxis] * 100

disease_annot = np.empty_like(cm_disease).astype(str)
for i in range(cm_disease.shape[0]):
    for j in range(cm_disease.shape[1]):
        disease_annot[i, j] = f'{cm_disease[i, j]}\n({cm_disease_percent[i, j]:.1f}%)'

# Severity confusion matrix
cm_severity = confusion_matrix(y_true_severity, y_pred_severity)
cm_severity_percent = cm_severity.astype('float') / cm_severity.sum(axis=1)[:, np.newaxis] * 100

severity_annot = np.empty_like(cm_severity).astype(str)
for i in range(cm_severity.shape[0]):
    for j in range(cm_severity.shape[1]):
        severity_annot[i, j] = f'{cm_severity[i, j]}\n({cm_severity_percent[i, j]:.1f}%)'

# PLOT MATRICES SIDE BY SIDE USING SUBPLOT 
plt.figure(figsize=(16, 7))

# Disease matrix (left)
plt.subplot(1, 2, 1)
sns.heatmap(
    cm_disease,
    annot=disease_annot,
    fmt='',
    cmap="Greens",
    xticklabels=disease_encoder.classes_,
    yticklabels=disease_encoder.classes_,
    annot_kws={'size': 9},
    cbar_kws={'label': 'Count'}
)
plt.title("Disease Confusion Matrix with Percentages", fontsize=14, fontweight='bold', pad=25)
plt.xlabel("Predicted", fontsize=12)
plt.ylabel("True", fontsize=12)

# Severity matrix (right)
plt.subplot(1, 2, 2)
sns.heatmap(
    cm_severity,
    annot=severity_annot,
    fmt='',
    cmap="Oranges",
    xticklabels=severity_encoder.classes_,
    yticklabels=severity_encoder.classes_,
    annot_kws={'size': 9},
    cbar_kws={'label': 'Count'}
)
plt.title("Severity Confusion Matrix with Percentages", fontsize=14, fontweight='bold', pad=25)
plt.xlabel("Predicted", fontsize=12)
plt.ylabel("True", fontsize=12)

plt.tight_layout()
plt.show()

# PRINT CLASSIFICATION REPORTS 
print("\n" + "="*60)
print("DISEASE CLASSIFICATION REPORT")
print("="*60)
print(classification_report(y_true_disease, y_pred_disease, target_names=disease_encoder.classes_))

"""
print("\n" + "="*60)
print("SEVERITY CLASSIFICATION REPORT")
print("="*60)
print(classification_report(y_true_severity, y_pred_severity, target_names=severity_encoder.classes_))
"""
print("\n" + "="*60)
print("SEVERITY CLASSIFICATION REPORT")
print("="*60)

severity_labels = np.arange(len(severity_encoder.classes_))

print(classification_report(
    y_true_severity,
    y_pred_severity,
    labels=severity_labels,
    target_names=severity_encoder.classes_,
    zero_division=0
))

# OVERALL ACCURACY 
disease_acc = np.mean(y_true_disease == y_pred_disease)
severity_acc = np.mean(y_true_severity == y_pred_severity)

print("\n" + "="*60)
print("OVERALL ACCURACY")
print("="*60)
print(f"Disease Classification Accuracy: {disease_acc:.2%}")
print(f"Severity Classification Accuracy: {severity_acc:.2%}")
# Out:
# Collecting predictions...
# Collected 296 samples
# ============================================================
# DISEASE CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#          AMD       0.99      1.00      1.00       185
#          DME       0.94      0.80      0.86        20
#          ERM       0.89      0.92      0.91        26
#           NO       0.98      1.00      0.99        55
#          RVO       1.00      1.00      1.00        10
#
#     accuracy                           0.98       296
#    macro avg       0.96      0.94      0.95       296
# weighted avg       0.98      0.98      0.98       296
#
#
# ============================================================
# SEVERITY CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#         mild       1.00      1.00      1.00        49
#     moderate       0.92      1.00      0.96        45
#       normal       1.00      0.96      0.98       100
#        other       1.00      0.88      0.93         8
#       severe       0.99      1.00      0.99        94
#
#     accuracy                           0.98       296
#    macro avg       0.98      0.97      0.97       296
# weighted avg       0.98      0.98      0.98       296
#
#
# ============================================================
# OVERALL ACCURACY
# ============================================================
# Disease Classification Accuracy: 97.97%
# Severity Classification Accuracy: 98.31%
